# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example with seaborn’s built-in Titanic dataset
df = sns.load_dataset("titanic")

sns.boxplot(x='sex', y='age', data=df)
plt.title("Age Distribution by Sex")
plt.show()
