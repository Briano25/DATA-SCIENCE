# %%
import pandas as pd
df = pd.read_excel(r'C:\\Users\\OJ 001\\Downloads\\staff_dataclean.xlsx')

print(df.tail())
print(df.info())
print(df.describe())

print(df.tail())
print(df.head())
# Out:
#       Emp ID First Name   Last Name  Gender          Department  Salary  \
# 234  VT04552  Theresita     Chasmer  Female  Product Management  106665
# 235  VT04627     Yvette        Bett    Male     Human Resources   76320
# 236  VT04681   Nickolai       Artin  Female  Product Management  110906
# 237  VT04905    Suchira  Bhanupriya  Female     Human Resources   29808
# 238  VT04984       Dell      Molloy    Male         Engineering   47362
#
#     Salary Bucket Start Date  FTE Employee type            Work location  \
# 234    Above 100k 2018-07-30  1.0     Temporary            Columbus, USA
# 235   50k to 100k 2021-07-06  0.8     Temporary                   Remote
# 236    Above 100k 2018-11-30  1.0     Temporary  Wellington, New Zealand
# 237     Under 50k 2018-07-10  0.3     Temporary         Hyderabad, India
# 238     Under 50k 2020-05-22  1.0     Temporary                   Remote
#
#      Tenure  Work Type           Full Name Workstation      Country
# ...
