# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\OJ 001\Desktop\DataScience\Start Data Analysis - new2.xlsx",sheet_name=5)
xls = pd.ExcelFile(r"C:\Users\OJ 001\Desktop\DataScience\Start Data Analysis - new.xlsx")
print(xls.sheet_names)
# Out:
# ['Cover Page', 'Pivot Table', 'Cleaned_Data', 'Raw Data', 'Sheet1 (2)']

# %% [markdown]
# first 10 rows and last 10 rows

# %%
print(df.head(10))
print(df.tail(10))
print(df.columns)
# Out:
#    Order ID       Date         Full Name  Gender  Age Country  Price  Units  \
# 0     10507 2023-06-18      Janet Murphy  Female   55      FR    400     91
# 1     10534 2023-06-23      Janice Clark  Female   60      IT    400     84
# 2     10537 2023-06-24  Charlotte Walker  Female   58      FR    320     84
# 3     10538 2023-06-24  Natalie Robinson  Female   49      FR    320     84
# 4     10542 2023-06-25      Doris Nguyen  Female   42      IT    400     84
# 5     10547 2023-06-26     Keith Roberts    Male   51      UK    250     84
# 6     10485 2023-06-14       Kelly Jones  Female   51      JP    320     82
# 7     10453 2023-06-07     Kennedi Singh    Male   50      ES    250     80
# 8     10477 2023-06-12   Joseph Mitchell    Male   59      FR    150     80
# 9     10486 2023-06-14    Steven Simpson    Male   48      US    150     80
#
#    Revenue Payment \nMethod  Salesperson
# 0  36400.0      Credit Card   Anna Perez
# 1  33440.0             Cash   Anna Perez
# ...

# %%
df = df.drop_duplicates()

# %%
print(df)
# Out:
#     Order ID       Date            Full Name  Gender  Age Country  Price  \
# 0      10507 2023-06-18         Janet Murphy  Female   55      FR    400
# 1      10534 2023-06-23         Janice Clark  Female   60      IT    400
# 2      10537 2023-06-24     Charlotte Walker  Female   58      FR    320
# 3      10538 2023-06-24     Natalie Robinson  Female   49      FR    320
# 4      10542 2023-06-25         Doris Nguyen  Female   42      IT    400
# ..       ...        ...                  ...     ...  ...     ...    ...
# 86     10530 2023-06-23        Madison Lohan  Female   26      IT    320
# 87     10540 2023-06-25         Diana Torres  Female   62      IT    250
# 88     10520 2023-06-21  Christina Fergusson  Female   26      JP    400
# 89     10545 2023-06-26        Lori Campbell  Female   20      JP    400
# 90     10489 2023-06-14          Joshua Reid    Male   36      ES    320
#
#     Units  Revenue Payment \nMethod  Salesperson
# ...

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order ID         91 non-null     int64
#  1   Date             91 non-null     datetime64[ns]
#  2   Full Name        91 non-null     object
#  3   Gender           91 non-null     object
#  4   Age              91 non-null     int64
#  5   Country          91 non-null     object
#  6   Price            91 non-null     int64
#  7   Units            91 non-null     int64
#  8   Revenue          91 non-null     float64
#  9   Payment
# Method  91 non-null     object
#  10  Salesperson      91 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 7.9+ KB

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is called df and has 'Sales Person' and 'Revenue' columns
plt.figure(figsize=(8, 5))  # Set the width and height of the figure in inches
plt.bar(df['Salesperson'], df['Revenue'], color='skyblue')  # Create the bar chart

# Add labels and title
plt.xlabel('Salesperson')
plt.ylabel('Revenue')
plt.title('Revenue by Sales Person')

# Optional: rotate x-axis labels for better readability
plt.xticks(rotation=45)

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()
